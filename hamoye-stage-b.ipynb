# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('dark_background')

# %%
data = pd.read_csv('../input/energy-dataset/energydata_complete.csv')

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
data.shape
# Out:
# (19735, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
for col in data.select_dtypes(exclude = 'O').columns:
    plt.figure(figsize = (10, 10))
    if data[col].nunique() > 3:
        sns.distplot(a = data[col], bins = 50)
        plt.title(f'Histogram plot of {col}')
    else:
        sns.countplot(data[col])
        plt.title(f'Count plot of {col}')
    plt.show()
    plt.close()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(data.drop(labels = ['date'], axis = 1).corr(method = 'pearson'), annot = True, fmt = '.3f')
plt.show()
plt.close()

# %% [markdown]
# From the analysis, a few inferences may be made:
# 1. The features for relative humidity and temperature generally exhibit high degrees of correlation.
# 2. The random variables (rv1 and rv2) seem to show little linear correlation with respect to the other variables.
# 3. All features show little linear correlation with the target (`Appliances` feature).
# 4. The pressure shows little to no linear relationship with respect to all other features.
# 5. The dew point temperature generally shows good statistical relationship with the humidity. This is as expected.

# %%
X, y = data.drop(labels = ['Appliances', 'lights', 'date'], axis = 1), data['Appliances']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
x_columns = X.columns

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train = pd.DataFrame(scaler_x.fit_transform(X_train), columns = x_columns)
X_test = pd.DataFrame(scaler_x.transform(X_test), columns = x_columns)

y_train = pd.Series(scaler_y.fit_transform(y_train), name = 'Appliances')
y_test = pd.Series(scaler_y.transform(y_test), name = 'Appliances')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f4cfac63cb25> in <module>
#       7 X_test = pd.DataFrame(scaler_x.transform(X_test), columns = x_columns)
#       8
# ----> 9 y_train = pd.Series(scaler_y.fit_transform(y_train), name = 'Appliances')
#      10 y_test = pd.Series(scaler_y.transform(y_test), name = 'Appliances')
#
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     334         # Reset internal state before fitting
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def get_error(model, X_test, y_test, loss = 'mae'):
    yhat = model.predict(X_test)
    if loss == 'mse':
        return mean_squared_error(y_test, yhat)
    elif loss == 'rmse':
        return mean_squared_error(y_test, yhat, squared = False)
    elif loss == 'rss':
        rss = np.sum(np.square(y_test - y_hat))
        return rss
    else:
        return mean_absolute_error(y_test, yhat)

# %%
dir(linear_model)

# %%
pa_reg = linear_model.PassiveAggressiveRegressor(max_iter = 10000)

# %%
pa_reg.fit(X_train, y_train)

# %%
pa_reg.score(X_test, y_test)

# %%
lin_reg = linear_model.LinearRegression()
lin_reg.fit(X_train, y_train)

# %%
lin_reg.score(X_test, y_test)

# %%
dir(pa_reg)

# %%
pa_reg.coef_

# %%
def get_weights_df(model, feat, col_name):
    '''
    Returns weight for each feature in feat
    '''
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
huber_reg = linear_model.HuberRegressor(max_iter = 10000, alpha = 0.0002)
huber_reg.fit(X_train, y_train)

# %%
huber_reg.score(X_test, y_test)

# %%
lasso_lars = linear_model.LassoLars(max_iter = 10000)
lasso_lars.fit(X_train, y_train)

# %%
lasso_lars.score(X_test, y_test)

# %%
X_train

# %%
X_train.columns

# %%
get_weights_df(model = pa_reg, feat = X_train, col_name = 'Lin Reg')

# %%
get_error(lin_reg, X_test, y_test, loss = 'mse')

# %% [markdown]
# # models = [lin_reg, pa_reg, huber_reg, ]
